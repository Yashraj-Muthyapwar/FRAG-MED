# %%
# Install Java (Synthea requires Java 8+)
# !apt-get install -y openjdk-17-jdk-headless

# Download the latest Synthea release
# !wget https://github.com/synthetichealth/synthea/archive/refs/heads/master.zip
# !unzip master.zip
# %cd synthea-master

# %%
OUTPUT_DIR = "/content/synthea/output_texas"
# !mkdir OUTPUT_DIR
POPULATION = 11000
STATE = "Texas"

print(f"Will generate {POPULATION} patients in {STATE}, output at {OUTPUT_DIR}")

# %%
# %cd /content/synthea-master

# !./run_synthea \
  -p {POPULATION} \
  --exporter.baseDirectory="{OUTPUT_DIR}" \
  --exporter.fhir.export=true \
  {STATE}
